# %%
import numpy as np
import random
import statistics

# %%
salary_list = [random.randint(50000, 100000) for _ in range(10000000)]

# %%
# %%timeit
statistics.median(salary_list)
# Out:
# 3.11 s ± 71 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
np.median(salary_list)
# Out:
# 555 ms ± 4.89 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
