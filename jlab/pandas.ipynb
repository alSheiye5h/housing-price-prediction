# %%
import pandas as pd

# %%
df = pd.read_csv('./share/cog_2023.csv')
df
# Out:
#       TYPECOM    COM   REG  DEP  CTCD  ARR  TNCC                    NCC  \
# 0         COM  01001  84.0   01   01D  012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002  84.0   01   01D  011     5    ABERGEMENT DE VAREY
# 2         COM  01004  84.0   01   01D  011     1      AMBERIEU EN BUGEY
# 3         COM  01005  84.0   01   01D  012     1    AMBERIEUX EN DOMBES
# 4         COM  01006  84.0   01   01D  011     1                AMBLEON
# ...       ...    ...   ...  ...   ...  ...   ...                    ...
# 37558     COM  97613   6.0  976  976D  NaN     0          M TSANGAMOUJI
# 37559     COM  97614   6.0  976  976D  NaN     1               OUANGANI
# 37560     COM  97615   6.0  976  976D  NaN     0               PAMANDZI
# 37561     COM  97616   6.0  976  976D  NaN     0                   SADA
# 37562     COM  97617   6.0  976  976D  NaN     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37563, step=1)

# %%
df.columns
# Out:
# Index(['TYPECOM', 'COM', 'REG', 'DEP', 'CTCD', 'ARR', 'TNCC', 'NCC', 'NCCENR',
#        'LIBELLE', 'CAN', 'COMPARENT'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37563 entries, 0 to 37562
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TYPECOM    37563 non-null  object
#  1   COM        37563 non-null  object
#  2   REG        34990 non-null  float64
#  3   DEP        34990 non-null  object
#  4   CTCD       34990 non-null  object
#  5   ARR        34973 non-null  object
#  6   TNCC       37563 non-null  int64
#  7   NCC        37563 non-null  object
#  8   NCCENR     37563 non-null  object
#  9   LIBELLE    37563 non-null  object
#  10  CAN        34845 non-null  object
#  11  COMPARENT  2618 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 3.4+ MB

# %%
df.select_dtypes(['object', 'int64', 'float64'])
# Out:
#       TYPECOM    COM   REG  DEP  CTCD  ARR  TNCC                    NCC  \
# 0         COM  01001  84.0   01   01D  012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002  84.0   01   01D  011     5    ABERGEMENT DE VAREY
# 2         COM  01004  84.0   01   01D  011     1      AMBERIEU EN BUGEY
# 3         COM  01005  84.0   01   01D  012     1    AMBERIEUX EN DOMBES
# 4         COM  01006  84.0   01   01D  011     1                AMBLEON
# ...       ...    ...   ...  ...   ...  ...   ...                    ...
# 37558     COM  97613   6.0  976  976D  NaN     0          M TSANGAMOUJI
# 37559     COM  97614   6.0  976  976D  NaN     1               OUANGANI
# 37560     COM  97615   6.0  976  976D  NaN     0               PAMANDZI
# 37561     COM  97616   6.0  976  976D  NaN     0                   SADA
# 37562     COM  97617   6.0  976  976D  NaN     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# ...

# %%
df.shape
# Out:
# (37563, 12)

# %%
df.convert_dtypes('int64', 'float64')
# Out:
#       TYPECOM    COM  REG  DEP  CTCD   ARR  TNCC                    NCC  \
# 0         COM  01001   84   01   01D   012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002   84   01   01D   011     5    ABERGEMENT DE VAREY
# 2         COM  01004   84   01   01D   011     1      AMBERIEU EN BUGEY
# 3         COM  01005   84   01   01D   012     1    AMBERIEUX EN DOMBES
# 4         COM  01006   84   01   01D   011     1                AMBLEON
# ...       ...    ...  ...  ...   ...   ...   ...                    ...
# 37558     COM  97613    6  976  976D  <NA>     0          M TSANGAMOUJI
# 37559     COM  97614    6  976  976D  <NA>     1               OUANGANI
# 37560     COM  97615    6  976  976D  <NA>     0               PAMANDZI
# 37561     COM  97616    6  976  976D  <NA>     0                   SADA
# 37562     COM  97617    6  976  976D  <NA>     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37563 entries, 0 to 37562
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TYPECOM    37563 non-null  object
#  1   COM        37563 non-null  object
#  2   REG        34990 non-null  float64
#  3   DEP        34990 non-null  object
#  4   CTCD       34990 non-null  object
#  5   ARR        34973 non-null  object
#  6   TNCC       37563 non-null  int64
#  7   NCC        37563 non-null  object
#  8   NCCENR     37563 non-null  object
#  9   LIBELLE    37563 non-null  object
#  10  CAN        34845 non-null  object
#  11  COMPARENT  2618 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 3.4+ MB

# %%
d = df.convert_dtypes()
# Out:
#       TYPECOM    COM  REG  DEP  CTCD   ARR  TNCC                    NCC  \
# 0         COM  01001   84   01   01D   012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002   84   01   01D   011     5    ABERGEMENT DE VAREY
# 2         COM  01004   84   01   01D   011     1      AMBERIEU EN BUGEY
# 3         COM  01005   84   01   01D   012     1    AMBERIEUX EN DOMBES
# 4         COM  01006   84   01   01D   011     1                AMBLEON
# ...       ...    ...  ...  ...   ...   ...   ...                    ...
# 37558     COM  97613    6  976  976D  <NA>     0          M TSANGAMOUJI
# 37559     COM  97614    6  976  976D  <NA>     1               OUANGANI
# 37560     COM  97615    6  976  976D  <NA>     0               PAMANDZI
# 37561     COM  97616    6  976  976D  <NA>     0                   SADA
# 37562     COM  97617    6  976  976D  <NA>     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37563 entries, 0 to 37562
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TYPECOM    37563 non-null  string
#  1   COM        37563 non-null  string
#  2   REG        34990 non-null  Int64
#  3   DEP        34990 non-null  string
#  4   CTCD       34990 non-null  string
#  5   ARR        34973 non-null  string
#  6   TNCC       37563 non-null  Int64
#  7   NCC        37563 non-null  string
#  8   NCCENR     37563 non-null  string
#  9   LIBELLE    37563 non-null  string
#  10  CAN        34845 non-null  string
#  11  COMPARENT  2618 non-null   Int64
# dtypes: Int64(3), string(9)
# memory usage: 3.5 MB

# %%
df.infer_objects()
# Out:
#       TYPECOM    COM   REG  DEP  CTCD  ARR  TNCC                    NCC  \
# 0         COM  01001  84.0   01   01D  012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002  84.0   01   01D  011     5    ABERGEMENT DE VAREY
# 2         COM  01004  84.0   01   01D  011     1      AMBERIEU EN BUGEY
# 3         COM  01005  84.0   01   01D  012     1    AMBERIEUX EN DOMBES
# 4         COM  01006  84.0   01   01D  011     1                AMBLEON
# ...       ...    ...   ...  ...   ...  ...   ...                    ...
# 37558     COM  97613   6.0  976  976D  NaN     0          M TSANGAMOUJI
# 37559     COM  97614   6.0  976  976D  NaN     1               OUANGANI
# 37560     COM  97615   6.0  976  976D  NaN     0               PAMANDZI
# 37561     COM  97616   6.0  976  976D  NaN     0                   SADA
# 37562     COM  97617   6.0  976  976D  NaN     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# ...
